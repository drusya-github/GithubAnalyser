# %%
import pandas as pd
import numpy as np

# %%
#reading the excel file

data = pd.read_excel("Github Stats.xlsx")

print(data)
# Out:
#                                  Project Name                 user_name  \
# 0                                    gpt4free                   xtekky
# 1                                    AudioGPT               AIGC-Audio
# 2                                    thinkgpt             alaeddine-13
# 3                                          IF               deep-floyd
# 4                             NeMo-Guardrails                   NVIDIA
# 5                                     LocalAI                go-skynet
# 6                          LLMsPracticalGuide               Mooler0410
# 7                              Track-Anything                gaomingqi
# 8                   Free-AUTO-GPT-with-NO-API  IntelligenzaArtificiale
# 9                                      jarvis                   Priler
# 10                                   WizardLM                 nlpxucan
# 11                                     k8sgpt                k8sgpt-ai
# ...

# %%
data
# Out:
#                                  Project Name                 user_name  \
# 1                                    gpt4free                   xtekky
# 2                                    AudioGPT               AIGC-Audio
# 3                                    thinkgpt             alaeddine-13
# 4                                          IF               deep-floyd
# 5                             NeMo-Guardrails                   NVIDIA
# 6                                     LocalAI                go-skynet
# 7                          LLMsPracticalGuide               Mooler0410
# 8                              Track-Anything                gaomingqi
# 9                   Free-AUTO-GPT-with-NO-API  IntelligenzaArtificiale
# 10                                     jarvis                   Priler
# 11                                   WizardLM                 nlpxucan
# 12                                     k8sgpt                k8sgpt-ai
# ...
